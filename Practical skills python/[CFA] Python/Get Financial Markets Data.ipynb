# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# yfinance is an open-source tool used to get market data from Yahoo 
# Let's install the library
# !pip install yfinance

# Let's import the library
import yfinance as yf 

# Pandas is used for dataframe and tabular data manipulation
import pandas as pd
# Out:
# Requirement already satisfied: yfinance in c:\anaconda\lib\site-packages (0.1.84)
# Requirement already satisfied: pandas>=0.24.0 in c:\anaconda\lib\site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in c:\anaconda\lib\site-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in c:\anaconda\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: requests>=2.26 in c:\anaconda\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Using Yahoo Finance tool to fetch all data related to stock of interest
# Note that data is obtained in an object, we can then apply methods to get specific data from the object
# Note that the output is returned in a Python dictionary
stock = yf.Ticker("AAPL")
stock
# Out:
# yfinance.Ticker object <AAPL>

# %%
# Let's explore some available methods, add a period "." and then click "tab" to display all available methods
# Note that actions indicate dividends and stock splits
# Recommendations indicate analyst's ratings
# Analysis indicates EPS targets 
# Info returns company information in a dictionary format
stock.info
# Out:
# {'regularMarketPrice': None, 'preMarketPrice': None, 'logo_url': ''}

# %%
# Let's obtain the company beta
# Remember that Beta is a measure of the security volatility compared to the market (S&P 500) 
# Stocks with betas greater than 1.0 are more volatile compared to S&P 500 
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 # Let's obtain the company beta
#       2 # Remember that Beta is a measure of the security volatility compared to the market (S&P 500)
#       3 # Stocks with betas greater than 1.0 are more volatile compared to S&P 500
# ----> 4 print("The company beta is = {}".format(stock.info['beta']))
#
# KeyError: 'beta'

# %%
# Let's obtain the company's free cash flow (FCF)  
# Free cash flow is the cash left in a company after it pays for its operating and capital expenditures.
print("The company cash is = ${}".format(stock.info['freeCashflow']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # Let's obtain the company's free cash flow (FCF)
#       2 # Free cash flow is the cash left in a company after it pays for its operating and capital expenditures.
# ----> 3 print("The company cash is = ${}".format(stock.info['freeCashflow']))
#
# KeyError: 'freeCashflow'

# %%
# Let's obtain the Price-to-Earnings (P/E) Ratio 
# Price-to-Earnings (P/E) ratio is calculated by dividing the current share price by its earnings per share (EPS) 
# High price-to-earnings ratio could indicate that the company's stock is overvalued 
# Example: S&P500 P/E ratio ranged from 5x in 1917 to 120x in 2009 right before the financial crisis 
# Trailing P/E is calculated using past performance by dividing the current stock price by total EPS earnings over the past 12 months.
print("The company Price-to-Earnings (P/E) ratio is = {} ".format(stock.info['trailingPE']))

# %%
# You can also obtain cash flow statements
stock.get_cashflow()

# %%
# Let's view some recommendations
stock.recommendations.tail(20)

# %%
# Using Yahoo Finance tool to fetch stock data
# Actions is used to obtain dividends and stock splits 
dividends_splits_df = stock.actions
dividends_splits_df

# %%
# Let's obtain the balance sheet for Apple
balance_df = stock.get_balance_sheet()
balance_df.round()
# Out:
#                                                 2022-09-24    2021-09-25  \
# Total Liab                                    3.020830e+11  2.879120e+11
# Total Stockholder Equity                      5.067200e+10  6.309000e+10
# Other Current Liab                            6.709400e+10  5.357700e+10
# Total Assets                                  3.527550e+11  3.510020e+11
# Common Stock                                  6.484900e+10  5.736500e+10
# Other Current Assets                          2.122300e+10  1.411100e+10
# Retained Earnings                            -3.068000e+09  5.562000e+09
# Other Liab                                    3.839400e+10  4.305000e+10
# Gains Losses Not Affecting Retained Earnings -1.110900e+10  1.630000e+08
# Other Assets                                  4.401100e+10  3.876200e+10
# Cash                                          2.364600e+10  3.494000e+10
# Total Current Liabilities                     1.539820e+11  1.254810e+11
# Short Long Term Debt                          1.112800e+10  9.613000e+09
# Other Stockholder Equity                     -1.110900e+10  1.630000e+08
# Property Plant Equipment                      5.253400e+10  4.952700e+10
# Total Current Assets                          1.354050e+11  1.348360e+11
# Long Term Investments                         1.208050e+11  1.278770e+11
# Net Tangible Assets                           5.067200e+10  6.309000e+10
# Short Term Investments                        2.465800e+10  2.769900e+10
# Net Receivables                               6.093200e+10  5.150600e+10
# Long Term Debt                                9.895900e+10  1.091060e+11
# Inventory                                     4.946000e+09  6.580000e+09
# Accounts Payable                              6.411500e+10  5.476300e+10
#
#                                                 2020-09-26    2019-09-28
# Total Liab                                    2.585490e+11  2.480280e+11
# Total Stockholder Equity                      6.533900e+10  9.048800e+10
# Other Current Liab                            4.786700e+10  4.324200e+10
# Total Assets                                  3.238880e+11  3.385160e+11
# Common Stock                                  5.077900e+10  4.517400e+10
# Other Current Assets                          1.126400e+10  1.235200e+10
# Retained Earnings                             1.496600e+10  4.589800e+10
# Other Liab                                    4.610800e+10  5.050300e+10
# Gains Losses Not Affecting Retained Earnings -4.060000e+08 -5.840000e+08
# Other Assets                                  3.395200e+10  3.297800e+10
# Cash                                          3.801600e+10  4.884400e+10
# Total Current Liabilities                     1.053920e+11  1.057180e+11
# Short Long Term Debt                          8.773000e+09  1.026000e+10
# Other Stockholder Equity                     -4.060000e+08 -5.840000e+08
# Property Plant Equipment                      4.533600e+10  3.737800e+10
# Total Current Assets                          1.437130e+11  1.628190e+11
# Long Term Investments                         1.008870e+11  1.053410e+11
# Net Tangible Assets                           6.533900e+10  9.048800e+10
# Short Term Investments                        5.292700e+10  5.171300e+10
# Net Receivables                               3.744500e+10  4.580400e+10
# Long Term Debt                                9.866700e+10  9.180700e+10
# Inventory                                     4.061000e+09  4.106000e+09
# Accounts Payable                              4.229600e+10  4.623600e+10

# %%
# Let's import datetime package 
import datetime
 
# Specify the starting date 
startDate = datetime.datetime(2021, 3, 1)
 
# Specify the end date 
endDate = datetime.datetime(2022, 3, 1)
 
# Obtain the stock price data
print(stock.history(start = startDate, end = endDate))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-01 00:00:00-05:00  122.464809  126.601398  121.514779  126.462852
# 2021-03-02 00:00:00-05:00  127.076420  127.383198  123.711729  123.820587
# 2021-03-03 00:00:00-05:00  123.513799  124.404453  120.574642  120.792358
# 2021-03-04 00:00:00-05:00  120.485579  122.316364  117.388088  118.882401
# 2021-03-05 00:00:00-05:00  119.723587  120.673616  116.348997  120.159012
# ...                               ...         ...         ...         ...
# 2022-02-22 00:00:00-05:00  164.236987  165.939293  161.419731  163.579971
# 2022-02-23 00:00:00-05:00  164.794473  165.401726  159.030555  159.349121
# 2022-02-24 00:00:00-05:00  151.892848  162.116601  151.315458  162.007095
# 2022-02-25 00:00:00-05:00  163.102129  164.376363  160.145503  164.107590
# 2022-02-28 00:00:00-05:00  162.325653  164.675025  161.698485  164.376373
#
#                               Volume  Dividends  Stock Splits
# Date
# 2021-03-01 00:00:00-05:00  116307900        0.0             0
# 2021-03-02 00:00:00-05:00  102260900        0.0             0
# 2021-03-03 00:00:00-05:00  112966300        0.0             0
# 2021-03-04 00:00:00-05:00  178155000        0.0             0
# 2021-03-05 00:00:00-05:00  153766600        0.0             0
# ...                              ...        ...           ...
# 2022-02-22 00:00:00-05:00   91162800        0.0             0
# 2022-02-23 00:00:00-05:00   90009200        0.0             0
# 2022-02-24 00:00:00-05:00  141147500        0.0             0
# 2022-02-25 00:00:00-05:00   91974200        0.0             0
# 2022-02-28 00:00:00-05:00   95056600        0.0             0
#
# [253 rows x 7 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY:**
# - **Write a code that performs the following:**
#     - **1. Obtains the beta for Meta, Apple, Spotify and P&G stocks**
#     - **2. Gets the circulating supply and closing price of Bitcoin**
#     - **3. Obtains the volume of Apple transactions on 2022-02-22**

# %% [markdown]
# # PRACTICE OPPORTUNITY SOLUTION

# %% [markdown]
# **PRACTICE OPPORTUNITY SOLUTION:**
# - **Write a code that performs the following:**
#     - **1. Obtains the beta for Meta, Apple, Spotify and P&G stocks**
#     - **2. Gets the circulating supply and closing price of Bitcoin**
#     - **3. Obtains the volume of Apple transactions on 2022-02-22**

# %%
stock = yf.Ticker("META")
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# The company beta is = 1.140369

# %%
stock = yf.Ticker("AAPL")
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# The company beta is = 1.246644

# %%
stock = yf.Ticker("SPOT")
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# The company beta is = 1.73236

# %%
stock = yf.Ticker("PG")
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# The company beta is = 0.399709

# %%
# Bitcoin 
# 'circulatingSupply': 19213206,
# 'previousClose': 16267.259
# Bitcoin and other cryptos are referenced with respect to the US dollar hence the naming convention BTC-USD, LTC-USD..etc.
crypto = yf.Ticker("BTC-USD")
crypto.info
# Out:
# {'companyOfficers': [],
#  'name': 'Bitcoin',
#  'startDate': 1367107200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency . Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,212,956. The last known price of Bitcoin is 16,245.5035676 USD and is down -2.87 over the last 24 hours. It is currently trading on 9849 active market(s) with $22,561,874,288.91 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 1,
#  'exchange': 'CCC',
#  'shortName': 'Bitcoin USD',
#  'exchangeTimezoneName': 'UTC',
#  'exchangeTimezoneShortName': 'UTC',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '0',
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'BTC-USD',
#  'messageBoardId': 'finmb_BTC_CCC',
#  'market': 'ccc_market',
#  'previousClose': 16267.259,
#  'regularMarketOpen': 16267.259,
#  'twoHundredDayAverage': 22556.553,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': 29451018240,
#  'regularMarketDayHigh': 16267.259,
#  'navPrice': None,
#  'averageDailyVolume10Day': 38699333165,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 16267.259,
#  'fiftyDayAverage': 19128.9,
#  'trailingAnnualDividendRate': None,
#  'open': 16267.259,
#  'toCurrency': 'USD=X',
#  'averageVolume10days': 38699333165,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': 19213206,
#  'regularMarketDayLow': 15960.514,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 29451018240,
#  'lastMarket': 'CoinMarketCap',
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 307349553152,
#  'volumeAllCurrencies': 29451018240,
#  'strikePrice': None,
#  'averageVolume': 37143018417,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 15960.514,
#  'ask': None,
#  'ytdReturn': None,
#  'askSize': None,
#  'volume': 29451018240,
#  'fiftyTwoWeekHigh': 59367.97,
#  'forwardPE': None,
#  'fromCurrency': 'BTC',
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 15682.692,
#  'bid': None,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': None,
#  'dayHigh': 16267.259,
#  'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin',
#  'regularMarketPrice': 15996.786,
#  'preMarketPrice': None,
#  'logo_url': ''}

# %%
stock = yf.Ticker("AAPL")

# Let's import datetime package 
import datetime
 
# Specify the starting date 
startDate = datetime.datetime(2022, 2, 20)
 
# Specify the end date 
endDate = datetime.datetime(2022, 2, 28)
 
# Obtain the stock price data
volume = stock.history(start = startDate, end = endDate)['Volume']

# %%
# print out the volume per day
volume
# Out:
# Date
# 2022-02-22 00:00:00-05:00     91162800
# 2022-02-23 00:00:00-05:00     90009200
# 2022-02-24 00:00:00-05:00    141147500
# 2022-02-25 00:00:00-05:00     91974200
# Name: Volume, dtype: int64

# %%
# Here's the volume on 2022-02-22
volume['2022-02-22 00:00:00-05:00']
# Out:
# 91162800

# %% [markdown]
# # EXCELLENT JOB!
