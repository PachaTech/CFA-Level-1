# %% [markdown]
# <hr>
#
# <H1><center> Checkpoint Exam 2:</H1></center>
# <H2><center> Attempt 1</H2></center>
#
#
# <hr>

# %% [markdown]
# **Question 1** \
# Which of the following statements is *most accurate* about a 3-for1 stock split in one of the securities in a price-weighted index?
#
# **Answer:** \
# <b><font color="green">A) The relative weights of the other securities in the index will increase.
# (Correct Answer)</font></b>
# \
# \
# B) The index value will decrease because the split security’s price will decrease.
# \
# \
# C) The index divisor will have to be increased to offset the price decrease of the split security.
# \
# \
# **Explanation:** \
# A split in one security will reduce its price and therefore its weight in the index. As a result, all other securities whose prices have not changed will increase their relative weight in the index. The index value will need to be *maintained* at the pre-split level. To maintain the index value, the index divisor will have to be adjusted down because the numerator is also adjusted down.
# \
# \
# (Module 42.1, LOS 42.e)
#
# <hr>
#
# **Question 2** \
# Can a firm that operates in a price-taker industry earn returns greater than its cost of capital in the long run?
#
# **Answer:** \
# A) No.
# \
# \
# <b><font color="green">B) Yes, if the firm is sustainably a low-cost producer. (Correct Answer)</font></b>
# \
# \
# C) Yes, if the firm differentiates its product from its competitors’ products.
#
#
# **Explanation:** \
# If a producer can sustain a cost advantage over time relative to its competitors, it can earn economic profits (returns greater than the cost of capital) even in a price-taker market. In such a market, each producer typically sells a product that is nearly identical to those of its competitors (i.e., little to no product differentiation).
# \
# \
# (Module 12.2, LOS 12.b) and (Module 45.2, LOS 45.c)
#
# <hr>
#
# **Question 3** \
# An analyst states, "Smith Company has a significantly higher degree of operating leverage than its industry peers." This statement is *most likely* based on analyzing Smith's costs by their:
#
#
# **Answer:** \
# A) nature.
# \
# \
# B) function.
# \
# \
# <b><font color="green">C) relationship with output.(Correct Answer)</font></b>
#
# **Explanation:** \
# Operating leverage results from having fixed operating costs. Classifying costs as fixed or variable refers to their relationship with output.
# \
# \
# (Module 45.2, LOS 45.d)
#
# <hr>
#
# **Question 4** \
# A country's banking industry consists of five banks, each with a 20% market share. One of the banks acquires a significant component of one of the other banks' operations, increasing its market share to 30% and decreasing the other bank's market share to 10%. As a result of this transaction, the Herfindahl-Hirschman Index (HHI) for the country's banking industry will:
#
#
#
# **Answer:** \
# <b><font color="green">A) increase. (Correct Answer)</font></b>
# \
# \
# B) decrease.
# \
# \
# C) remain unchanged.
#
# **Explanation:** \
# The HHI will increase.
# \
# \
# Initial HHI (prior to merger) = $20^2 + 20^2  + 20^2 + 20^2 + 20^2 = 2,000$.
# \
# \
# Post-transaction HHI (post merger) = $30^2 + 20^2 + 20^2 + 20^2 + 10^2 = 2,200.$
#
#
# >**Note**
# \
# HHI = $S1^2 + S2^2 + S3^2 + \ldots Sn^2$
# >Where:
# >
# >S1, S2, etc… – refers to the percentage market share that various companies hold in the given industry
#
#
# >
#
# <p><br></p>
#
# (Module 12.3, LOS 12.e) and (Module 46.1, LOS 46.c)
#
# <hr>
#
# **Question 5** \
# An analyst engaging in PESTLE analysis of an industry is most likely to evaluate its:
#
#
# **Answer:** \
# A) liquidity pressures.
# \
# \
# <b><font color="green">B) technological influences.(Correct Answer)</font></b>
# \
# \
# C) equity market capitalization.
#
# **Explanation:** \
# PESTLE analysis refers to evaluating the outside influences on an industry:
#
# >**P**olitical \
# **E**conomic \
# **S**ocial \
# **T**echnological \
# **L**egal\
# **E**nvironmental
#
# (Module 46.2, LOS 46.d)
#
# <hr>
#
# **Question 6** \
# A historical base rate convergence approach is *most likely* to be appropriate for forecasting the sales growth of a(n):
#
#
# **Answer:** \
# A) online travel agency.
# \
# \
# <b><font color="green">B) chain of grocery stores.
# (Correct Answer)</font></b>
# \
# \
# C) high-fashion clothing company.
# \
# \
# **Explanation:** \
# The historical base rate convergence approach is best suited for companies in non-cyclical or well-established industries. A grocery chain likely faces demand for its products that does not fluctuate significantly with economic cycles. An online travel agency or a high-fashion clothing company most likely faces more cyclical demand for their products.
# \
# \
# (Module 47.1, LOS 47.b)
#
# <hr>
#
# **Question 7** \
# Grovers Inc. manufactures children's toys in a country where it has a significant share of the market and barriers to entry are high. Proxe Corp. manufactures underwear globally in a highly competitive environment. Recent innovations in machinery have reduced operating expenses in both Govers's and Proxe's industries. The reduced operating expenses are *most likely* to:
#
#
#
# **Answer:** \
# A) increase operating margins for both companies.
# \
# \
# <b><font color="green">B) increase operating margins more for Grovers than for Proxe. (Correct Answer)</font></b>
# \
# \
# C) have little impact on the operating margins of either company.
# \
# \
# **Explanation:** \
# Because Grovers operates in a market with weaker competitive forces than Proxe, Grovers likely has more pricing power than Proxe. **Therefore**, Grovers can likely keep its pricing unchanged so that its lower operating costs will increase its operating margins. By contrast, in Proxe's market, competitors are more likely to respond to decreased operating expenses by decreasing their prices and attempting to gain market share. Proxe will likely need to decrease its prices to defend its market share, which will keep pressure on its operating margins.
# \
# \
# (Module 46.2, LOS 46.d) and (Module 47.1, LOS 47.c)
#
# <hr>
#
#
# **Question 8** \
# AgroCorp Inc., a Canadian grain producer, recently issued a five-year floating rate note with a face value of CAD 90,000,000. The bond pays semiannual interest based on the Canadian Overnight Repo Rate (CORRA) plus 150 bps per year. If CORRA is 0.50% in the final interest period, at maturity AgroCorp will pay bondholders:
#
#
# **Answer:** \
# A) CAD 1,800,000.
# \
# \
# <b><font color="green">B) CAD 90,900,000. (Correct Answer)</font></b>
# \
# \
# C) CAD 91,800,000.
# \
# \
# **Explanation:** \
# At maturity, AgroCorp will have to pay both the final coupon and the principal value of the bond to investors. The coupon rate is `CORRA + 0.50% = 2.00%` annually. For the last six-month period,
# \
# the coupon interest is `2% / 2 × CAD 90,000,000 = CAD 900,000`.
# \
# Therefore, AgroCorp will have to pay bondholders `CAD 90,000,000 + CAD900,000 = CAD 90,900,000.`
# \
# \
# (Module 46.2, LOS 46.d) and (Module 47.1, LOS 47.c)
#
# <hr>
#
# **Question 9** \
# Following a one-notch downgrade by Standard & Poor's of a corporate bond from investment grade to non-investment grade, the bond would carry a credit rating of:
#
#
#
# **Answer:** \
# A) BBB–, and the bond yield would likely increase.
# \
# \
# <b><font color="green">B) BB+, and the bond yield would likely increase. (Correct Answer)</font></b>
# \
# \
# C) BB+, and the bond yield would likely decrease.
# \
# \
# **Explanation:** \
# A one-notch downgrade from investment grade to non-investment grade (high-yield) rating implies a downgrade from BBB– to BB+. A rating downgrade typically increases the bond's yield.
# \
# \
# (Module 51.1, LOS 51.a) and (Module 62.1, LOS 62.b)
#
# <img src="https://wolfstreet.com/wp-content/uploads/2019/01/US-credit-ratings-scale-Moodys-SP-Fitch.png">
# <hr>
#
# **Question 10** \
# BAMS Brokers is looking to enter a reverse repurchase agreement involving a security that is difficult to borrow. In this scenario, BAMS would:
#
#
# **Answer:** \
# <b><font color="green">A) buy the security, and the repo rate is likely to be below the general collateral repo rate. (Correct Answer)</font></b>
# \
# \
# B) sell the security, and the repo rate is likely to be above the general collateral repo rate.
# \
# \
# C) buy the security, and the repo rate is likely to be above the general collateral repo rate.
#
#
# **Explanation:** \
# To carry out a reverse repo, BAMS is <u>the buyer</u> of the security (collateral) and therefore lends money; from the seller's side, this is a repo agreement and the seller is the borrower. *Because the security is difficult to borrow (special collateral)*, the repo rate is likely to be <u>below</u> the general collateral repo rate.
# \
# \
# (Module 52.1, LOS 52.b)
#
# <hr>

# %% [markdown]
# **Question 11** \
# Lando Bank recently issued a 3-year floating rate note with quarterly interest of MRR + 0.60%. The MRR is currently 0.40%. Six months later, the required margin is 40 bps (0.40%). On reset date, the floating rate note will most likely be priced at:
#
#
# **Answer:** \
# A) par.
# \
# \
# B) a discount.
# \
# \
# <b><font color="green">C) a premium. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# The required margin declined from `60 bps` to `40 bps`, indicating that Lando's credit risk has <u>improved</u> (the market now requires a *lower spread above the MRR*). Because
# \
# `the required margin (40 bps)` is below the `quoted margin (60 bps)`, the floating rate note will be trading at a premium.
# \
# \
# (Module 56.1, LOS 56.a)
#
# <hr>
#
# **Question 12** \
# A fixed income trader expects that the yield of a 5-year, 5% annual coupon bond with a Macaulay duration of 4.25 will <u>decrease from 7% to 6%</u>. As a result, the anticipated percentage increase in the bond's price is:
#
#
# **Answer:** \
# A) 4.25%.
# \
# \
# <b><font color="green">B) less than 4.25%. (Correct Answer)</font></b>
# \
# \
# C) more than 4.25%..
#
#
# **Explanation:** \
# We can estimate the bond's price change based on modified duration. We can calculate modified duration by dividing Macaulay duration by the yield:
# $$
# \text{ModDur } = \large \frac{\text{MacDur}}{1 + r} \small =  \large \frac{4.25}{1.06} = 4.009
# $$
# \
# \
# As a result, the estimated price increase of the bond for a `100 bps decrease in yield is 4.009%`.
#
#
# (Module 59.1, LOS 59.a)
#
# <hr>
#
# **Question 13** \
# Consider the following bonds, all option-free and from the same issuer:
#
# * Bond X: 4-year, zero coupon bond
# * Bond Y: 10-year, zero coupon bond
# * Bond Z: 10-year, 5% coupon bond
#
# Which of the bonds is *most likely* to have the greatest convexity?
#
#
# **Answer:** \
# A) Bond X.
# \
# \
# <b><font color="green">B) Bond Y. (Correct Answer)</font></b>
# \
# \
# C) Bond Z.
#
#
# **Explanation:** \
# Similar to duration, a bond's convexity increases as its time-to-maturity increases and the coupon rate decreases. As a result, a long-term, zero-coupon bond such as Bond Y would have greater convexity than a coupon bond of the same maturity or a shorter-term zero-coupon bond.
# \
# \
# (Module 60.1, LOS 60.a)
#
# <hr>
#
# **Question 14** \
# A pension fund manager is analyzing the long-term bonds of three countries. The manager wants to invest in the bonds of the country with the strongest credit profile.
#
# <table>
# <thead>
#   <tr>
#     <th>Characteristics</th>
#     <th>Country A</th>
#     <th>Country B</th>
#     <th>Country C</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Real GDP growth (%)</td>
#     <td>0.50</td>
#     <td>0.75</td>
#     <td>1.00</td>
#   </tr>
#   <tr>
#     <td>Long-term external debt/GDP (%)</td>
#     <td>53.2</td>
#     <td>62.5</td>
#     <td>48.1</td>
#   </tr>
#   <tr>
#     <td>Short-term debt / Long-term debt (%)</td>
#     <td>35.0</td>
#     <td>24.7</td>
#     <td>28.9</td>
#   </tr>
#   <tr>
#     <td>FX reserves/GDP (%)</td>
#     <td>17.0</td>
#     <td>20.5</td>
#     <td>20.1</td>
#   </tr>
# </tbody>
# </table>
#
# Based on the table above, the manager would *most likely* select:
#
#
#
# **Answer:** \
# A) Country A.
# \
# \
# B) Country B.
# \
# \
# <b><font color="green">C) Country C. (Correct Answer)</font></b>
#
#
# **Explanation:** \
# Country C would most likely have the highest credit quality because it has the <u>lowest <b>long-term external debt-to-GDP ratio</b></u>. Although Country B has marginally higher FX reserves-to-GDP ratio and lower refinancing risk (lower relative short-term debt), it has a significantly higher external debt burden and slightly weaker economic growth.
# \
# \
# (Module 63.1, LOS 63.a)
#
# <hr>
#
#
# **Question 15** \
# Azzio Corp. is a frequent debt issuer and issues debt with various priority of claims. An investor who wants to invest in an Azzio bond that has the highest priority of claims would *most likely* purchase its:
#
#
# **Answer:** \
# <b><font color="green">A) 10-year, second lien debt.
# (Correct Answer)</font></b>
# \
# \
# B) The index value will decrease because the split security’s price will decrease.
# \
# \
# C) The index divisor will have to be increased to offset the price decrease of the split security.
# \
# \
# **Explanation:** \
# Second lien debt is a secured debt obligation, and as such ranks ahead of all unsecured obligations. All senior unsecured creditors would be treated as the same class in bankruptcy, regardless of debt maturity. Therefore, bondholders of the 6-month and 20-year senior unsecured debt have the same priority of claims.
# \
# \
# (Module 64.1, LOS 64.c)
#
# <hr>
#
# **Question 16** \
# TKA Industries (TKAI) is a European semiconductor manufacturer with €2.5 billion senior unsecured corporate bonds outstanding. In 20X1, TKAI sold €1 billion of its balance sheet receivables to TKA Trust, a special purpose entity, which then issued €800 million senior bonds and €200 million subordinated bonds. In 20X3, TKAI issued a further €1.3 billion senior unsecured corporate bonds. Which of the following statements about these bonds' seniority is <u>*most accurate*</u>? TKAI's:
#
#
# **Answer:** \
# A) €1.3 billion corporate bonds are senior to TKA Trust’s subordinated bonds.
# \
# \
# B) €2.5 billion corporate bonds have the same seniority as TKA Trust’s senior bonds.
# \
# \
# <b><font color="green">C) €1.3 billion corporate bonds have the same seniority as its €2.5 billion corporate bonds. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# TKAI's €2.5 billion and €1.3 billion <u>senior unsecured obligations have the <b>same priority of claims</b> and therefore **seniority**, regardless of when they were issued and maturity</u>.
# \
# Seniority does not apply between TKA Trust and TKAI because they are two distinct entities; TKA Trust is an SPE and is therefore bankruptcy remote from TKAI.
# \
# \
# (Module 64.1, LOS 64.c) and (Module 65.1, LOS 65.b)
#
# <hr>
#
# **Question 17** \
# Consider the following 5-year asset-backed notes issued by Zollo Trust:
#
# <table>
# <thead>
#   <tr>
#     <th>Tranche</th>
#     <th>Face value</th>
#     <th>Interest rate</th>
#     <th>Credit enhancement</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Class A notes</td>
#     <td>\$80 million</td>
#     <td>MRR + 0.2%</td>
#     <td>-</td>
#   </tr>
#   <tr>
#     <td>Class B notes</td>
#     <td>\$10 million</td>
#     <td>MRR + 1.0%</td>
#     <td>Subordinated to Class A notes</td>
#   </tr>
#   <tr>
#     <td>Class C notes</td>
#     <td>\$7 million</td>
#     <td>MRR + 2.0%</td>
#     <td>Subordinated to Class A and Class B notes</td>
#   </tr>
#   <tr>
#     <td>Class D notes</td>
#     <td>\$3 million</td>
#     <td>MRR + 3.0%</td>
#     <td>Subordinated to Class A, Class B and Class C notes</td>
#   </tr>
# </tbody>
# </table>
#
# During the year 20X3, MRR was 2.0% and defaults in the pool were \\$15 million. An investor who held \\$5 million of Class A notes and \\$5 million of Class B notes would receive interest for the year *closest* to:
#
#
#
# **Answer:** \
# A) \\$110,000.
# \
# \
# <b><font color="green">B) \\$185,000. (Correct Answer)</font></b>
# \
# \
# C) \\$260,000.
# \
# \
# **Explanation:**
#
# Given a default of \\$15 million in the pool, Class D notes would absorb the first \\$3 million in losses, Class C notes would absorb the next $7 million, and Class B notes would absorb the remaining \\$5 million in losses. Because half the pool supporting the Class B notes is in default, each investor in the Class B notes receives half of the scheduled interest payments. Investors in Class A notes receive full interest payments.
# \
# \
# Interest received for Class A notes: \\$5 million × (2.0% + 0.2%) = \\$110,000
# \
# \
# Interest received for Class B notes: 1/2 × \\$5 million × (2.0% + 1.0%) = \\$75,000
# \
# \
# Total interest received = \\$110,000 + \\$75,000 = \\$185,000
# \
# \
# (Module 66.1, LOS 66.b)
#
# <hr>
#
# **Question 18** \
# A sequential-pay collateralized mortgage obligation (CMO) has three tranches: Tranche A matures in 2 years, Tranche B matures in 5 years, and Tranche C matures in 10 years. An investor who expects a gradual decline in interest rates over the next 5 years would *most likely* be concerned about:
#
#
#
# **Answer:** \
# A) contraction risk, and therefore would prefer Tranche A.
# \
# \
# B) extension risk, and therefore would prefer Tranche B.
# \
# \
# <b><font color="green">C) contraction risk, and therefore would prefer Tranche C. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# The investor would be concerned about contraction risk, or the risk that decreasing interest rates will cause interest payments to decline and principal to be prepaid more quickly than anticipated over the next 5 years. The strongest protection against contraction risk in a sequential-pay CMO comes from the longest maturity, in this case Tranche C.
# \
# \
# (Module 67.1, LOS 67.a, LOS 67.c)
#
# <hr>
#
# **Question 19** \
# BamBam Inc. is a Canadian manufacturer of specialized machinery to produce pet food. BamBam exports its machinery to clients in many different countries. A recent transaction involves the sale of a machine to a client in France. The contract date is May 31st, the delivery date is 60 days later, and the client will make payment to BamBam in Euros. Which of the following reasons best explains why BamBam should use a derivative rather than a spot market transaction to manage the currency risk of the contract?
#
#
# **Answer:** \
# A) BamBam is selling a machine at a contract price in euros but incurs costs in Canadian dollars.
# \
# \
# B) BamBam is unable to sell euros today to offset the contract price of the machinery delivered to the French client.
# \
# \
# <b><font color="green">C) BamBam faces a 60-day timing difference between the contract date and the delivery date when it is paid for the machine by the French client. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# A 60-day timing difference exists between the contract and the delivery date when BamBam is paid for the machine in EUR. A derivative contract in which the underlying EUR/CAD forward rate is agreed upon today and exchanged on the delivery date allows BamBam to hedge or offset the CAD value of the future EUR payment. Therefore, the derivative is a more suitable contract to address the currency risk of the transaction than a spot market sale of EUR.
# \
# \
# (Module 68.1, LOS 68.a)
#
# <hr>
#
#
# **Question 20** \
# An investor has <font color="red">**written**</font> a 3-month call option on an asset at \\$35 for \\$4 when the asset is trading at \\$38. If, at expiration, the asset price is \\$37, the investor will have a:
#
#
#
# **Answer:** \
# A) payoff of \\$2 at expiration.
# \
# \
# <b><font color="green">B)profit of \\$2 at expiration. (Correct Answer)</font></b>
# \
# \
# C) loss of $2 at expiration.
# \
# \
# **Explanation:** \
# A writer of the call will have a negative payoff of \\$2 at expiration for a profit of `4 – 2 = $2`.
# \
# `37-35 = 2`
# \
# \
# (Module 69.2, LOS 69.b)
#
# <hr>

# %% [markdown]
# **Question 21** \
# Ruby Inc. is a company in based in the United States that has recently acquired a subsidiary located in Switzerland. The company is concerned about the impact of fluctuations in the USD/CHF exchange rate on the value of the Swiss subsidiary. Which type of hedge would be most appropriate for Ruby to consider?
#
#
# **Answer:** \
# A) Cash flow hedge.
# \
# \
# B) Fair value hedge.
# \
# \
# <b><font color="green">C) Net investment hedge. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# A net investment hedge is designated as offsetting the foreign exchange risk of the equity of a foreign operation and can be done with a currency swap or forward, for example. A cash flow hedge is meant to absorb the variable cash flow of a floating-rate asset or liability. A fair value hedge is meant to offset fluctuations in the fair value of an asset or liability.
# \
# \
# (Module 70.1, LOS 70.b)
#
# <hr>
#
# **Question 22** \
# Which of the following *least likely* illustrates the correct way to calculate the forward price at time T of an asset (S) that has both costs and benefits of holding the asset, in addition to the opportunity cost of funds (Rf)?
#
#
# **Answer:** \
# <b><font color="green">A) $\big[\text{S}_0 + \text{PV}_0(\text{benefits}) – \text{PV}_0(\text{costs})\big] (1 + \text{Rf})^\text{T}$. (Correct Answer)</font></b>
# \
# \
# B) $\big[\text{S}_0 - \text{PV}_0(\text{benefits}) + \text{PV}_0(\text{costs})\big] (1 + \text{Rf})^\text{T}$.
# \
# \
# <b><font color="green">C) $\text{S}_0(1 + \text{Rf})^\text{T} + \text{FV}^\text{T}(\text{costs}) – \text{FV}^\text{T}(\text{benefits})$ (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# The benefits of holding the asset are subtracted and the costs of holding the asset are added when calculating the no-arbitrage forward price.
# \
# \
# $\big[\text{S}_0 – \text{PV}_0(\text{benefits}) + \text{PV}_0(\text{costs})\big](1 + \text{Rf})^\text{T} = \text{S}_0(1 + \text{Rf})^\text{T} + \text{FV}^\text{T}(\text{costs}) – \text{FV}^\text{T}(\text{benefits})$, and either can be used to calculate the no-arbitrage forward price.
# \
# \
# (Module 71.1, LOS 71.b)
#
# <hr>
#
# **Question 23** \
# Assuming all other parameters remain unchanged, what is the impact of a decrease in the risk-free rate after the inception of a forward contract on the contract's mark-to-market value to the forward buyer? The forward contract's mark-to-market value to the forward buyer will:
#
#
# **Answer:** \
# A) Increase.
# \
# \
# <b><font color="green">B) decrease. (Correct Answer)</font></b>
# \
# \
# C) remain unchanged.
# \
# \
# **Explanation:** \
# The mark-to-market value from the forward buyer's perspective is equal to $\text{V}_t\text{(T)}$ as follows:
# \
# \
# $\text{V}_t\text{(T)} = \text{S}_t – \text{F}0(\text{T})(1 + \text{r})^{–(\text{T–t})}$
# \
# \
# A decrease in the <u>risk-free rate</u> following the inception of a forward contract will <u>increase the present value of the forward price $\text{F}_0(\text{T})$</u>, which will <font color="red">decrease</font> the mark-to-market value from the contract buyer's perspective.
# \
# \
# (Module 72.1, LOS 72.a)
#
# <hr>
#
# **Question 24** \
# The price of a forward contract:
#
#
# **Answer:** \
# <b><font color="green">A) is stated in the contract. (Correct Answer)</font></b>
# \
# \
# B) equals zero at contract initiation.
# \
# \
# C) may fluctuate during the contract’s life.
# \
# \
# **Explanation:** \
# The *price* of a forward contract is the price at which the underlying asset will be exchanged at settlement. <u>This price is stated in the contract</u> and determined such that the *value* of the contract is equal to zero at initiation. The value may vary during the life of the contract, but the price does not.
# \
# \
# (Module 73.1, LOS 73.a)
#
# <hr>
#
# **Question 25** \
# At initiation of a forward contract and a futures contract with identical terms, their prices are *most likely* to be different if:
#
#
# **Answer:** \
# A) the spot price is highly volatile.
# \
# \
# B) the forward contract is marked to market daily.
# \
# \
# <b><font color="green">C) short-term interest rates are negatively correlated with futures prices. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# Forward and futures prices may differ for otherwise identical contracts if interest rates are positively or negatively correlated with futures prices. The difference arises from the fact that futures are marked to market daily while forwards typically are not. A futures contract holder can earn interest on mark-to-market gains and faces an opportunity cost of interest of mark-to-market losses.
# \
# \
# (Module 73.1, LOS 73.b)
#
# <hr>
#
# **Question 26** \
# At inception, a one-year quarterly pay fixed-for-floating interest rate swap:
#
#
# **Answer:** \
# A) has four unknown future payments.
# \
# \
# <b><font color="green">B) has expected payments with a present value of zero. (Correct Answer)</font></b>
# \
# \
# C) can be replicated with a series of forward rate agreements at market rates.
# \
# \
# **Explanation:** \
# At the inception of a swap, the present value of the expected cash flows from the swap is zero. *The fixed and floating rates for the first payment are known at inception*, so the net payment at the end of the first period is <u>known</u> at inception. We can create a position equivalent to the swap with market-rate FRAs, but it will not replicate the swap because the fixed rates on the market-rate FRAs are not all equal.
# \
# \
# (Module 74.1, LOS 74.a)
#
# <hr>
#
# **Question 27** \
# The price of an interest rate swap is *most accurately* described as:
#
#
# **Answer:** \
# A) zero at the initiation of the swap contract.
# \
# \
# B) decreasing when the reference rate increases.
# \
# \
# <b><font color="green">C) constant throughout the life of the swap contract. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# The price of an interest rate swap is the fixed interest rate specified in the contract. The value of an interest rate swap is typically zero at initiation and may vary during the life of the contract as expected future interest rates change.
# \
# \
# (Module 74.1, LOS 74.b)
#
# <hr>
#
# **Question 28** \
# Other things equal, cash dividends on a stock during an option's life:
#
# **Answer:** \
# A) decrease the value of call options and put options on the stock.
# \
# \
# B) increase the value of call options on the stock and decrease the value of put options on the stock.
# \
# \
# <b><font color="green">C) decrease the value of call options on the stock and increase the value of put options on the stock. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# Dividend payments <u>decrease the price of the underlying stock</u>. This makes calls less valuable and puts more valuable.
# \
# \
# (Module 75.1, LOS 75.c)
#
# <hr>
#
# **Question 29** \
# European call and put options with an exercise price of 60 and an expiration date of August 31 are available on an underlying asset. The present value of the price of a forward contract on the same asset today is <u>*closest*</u> to the:
#
#
# **Answer:** \
# <b><font color="green">A) call price minus the put price plus the present value of 60. (Correct Answer)</font></b>
# \
# \
# B) put price minus the call price plus the present value of 60.
# \
# \
# C) call price plus the put price minus the present value of 60.
# \
# \
# **Explanation:** \
# The put-call-forward parity relationship states that at the initiation of a forward contract, $\text{F}_0(\text{T}) (1 + \text{Rf})^{\text{-T}} = \text{c}_0 − \text{p}_0 + \text{X} (1 + \text{Rf})^{\text{-T}}$. In this question, the exercise price, $\text{X}$, is $60$.
# \
# \
# (Module 76.1, LOS 76.b)
#
# <hr>
#
# **Question 30** \
# In a one-period binomial model of an option that uses probabilities of an up-move and a down-move, the probabilities are:
#
# **Answer:** \
# A) assumed to be equal to 0.5.
# \
# \
# B) estimated based on historical data.
# \
# \
# <b><font color="green">C) calculated from the model’s inputs. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# The risk-neutral probabilities used in a one-period binomial model for options are derived from the *risk-free rate* and the sizes (`pstep`) of the up-moves and down-moves in the model.
# \
# \
# (Module 77.1, LOS 77.b)
#
# <hr>

# %% [markdown]
# **Question 31** \
# Nagle Company produces a commodity with a market price of \\$3.25 per unit. Nagle forecasts production and sales of 900,000 units over the next quarter. Nagle's variable cost per unit is \\$3.75, and <u>fixed operating costs</u> are \\$400,000. Based on these projections, it is *most likely* that:
#
#
# **Answer:** \
# A) Nagle’s contribution margin for the quarter is \\$0.50 per unit.
# \
# \
# <b><font color="green">B) Nagle will experience an operating loss of \\$400,000 for the quarter. (Correct Answer)</font></b>
# \
# \
# C) Nagle’s breakeven quantity of sales for the quarter is 1,200,000 units.
# \
# \
# **Explanation:** \
# Nagle has no breakeven quantity of sales because the price per unit is less than Nagle's variable cost per unit (i.e., the contribution margin is negative). Nagle's operating income would be `900,000($3.25 − $3.75) – $400,000 = –$850,000` by operating in the next period, but Nagle can <u>limit</u> its operating loss to its <u>fixed operating costs</u> of `$400,000` by shutting down temporarily.
# \
# \
# (Module 12.1, LOS 12.a) and (Module 45.2, LOS 45.d)
#
# <hr>
#
# **Question 32** \
# A dark pool is best described as:
#
# **Answer:** \
# A) an exchange with low trading volume.
# \
# \
# B) the loans underlying a mortgage-backed security.
# \
# \
# <b><font color="green">C) an alternative trading system that does not reveal current orders. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# An alternative trading system that does not reveal current client orders is referred to as a dark pool. Dark pools provide traders anonymity by not revealing their orders to potential counterparties.
# \
# \
# (Module 41.1, LOS 41.d)
#
# <hr>
#
# **Question 33** \
# Jacques Fontenot wants to place an order to purchase 10,000 shares of BQ Inc. at a price of €75.00 or below. The shares are currently trading for €82.10 bid and €82.20 ask. What type of order should Fontenot place?
#
# **Answer:** \
# A) Market order.
# \
# \
# B) Stop loss order.
# \
# \
# <b><font color="green">C) Limit order. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# This is a limit order. If the shares trade for €75 or below, Fontenot's broker will purchase the shares for him. If Fontenot had wanted to sell shares he already owned when the price dropped to €75.00, that would be a stop loss order.
# \
# \
# (Module 41.3, LOS 41.h)
#
# <hr>
#
# **Question 34** \
# In a call market:
#
#
# **Answer:** \
# <b><font color="green">A) a single price that clears the market is set periodically. (Correct Answer)</font></b>
# \
# \
# B) trades may occur at any time during market hours.
# \
# \
# C) prices are set by the highest dealer bid and the lowest dealer ask price.
# \
# \
# **Explanation:** \
# Trades in a call market occur at specified times. All orders are accumulated, and a single negotiated price is set that clears the market.
# \
# \
# (Module 41.3, LOS 41.j)
#
# <hr>
#
# **Question 35** \
# A mutual fund uses a momentum strategy-buying stocks that have been increasing in price and selling stocks that have been decreasing in price. The *most appropriate* type of equity index to use as a <u>benchmark</u> is:
#
#
# **Answer:** \
# A) equal weighted.
# \
# \
# B) fundamental weighted.
# \
# \
# <b><font color="green">C) market capitalization weighted. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# In a market capitalization weighted index, the relative weight increases for constituent stocks that have outperformed other stocks in the index. For this reason, a market capitalization weighted index is an appropriate benchmark for a fund using a momentum strategy (buying securities that have been increasing in price and selling securities that have been decreasing in price). Fundamental weighted indices often have a value tilt, not a momentum tilt. With equal weighting there is no tilt toward momentum.
# \
# \
# (Module 42.1, LOS 42.d)
#
# <hr>
#
# **Question 36** \
# Sam Grant, CFA, publishes the Grant 50 Index, which consists of value stocks with small market capitalizations. The Grant 50 Index is best described as a:
#
# **Answer:** \
# <b><font color="green">A) style index. (Correct Answer)</font></b>
# \
# \
# B) sector index.
# \
# \
# C) value weighted index.
# \
# \
# **Explanation:** \
# Style indexes measure the returns to strategies that are differentiated by market capitalization or by value versus growth. A sector index measures the returns for an industry sector such as financials. Although market capitalization is one of the criteria for inclusion in the index, this does not suggest the index is value weighted.
# \
# \
# (Module 42.2, LOS 42.j)
#
# <hr>
#
# **Question 37** \
# A market researcher is analyzing the efficiency of the Oceania Securities Exchange (OSE). Market prices appear to incorporate all prior price and volume information in a timely manner but are slow to incorporate the true value impact of earnings surprises. The researcher determines that specialists on the floor of the OSE consistently earn positive risk-adjusted returns on average. Which of the three forms of the Efficient Market Hypothesis best describes the OSE market?
#
# **Answer:** \
# <b><font color="green">A) Weak-form efficient. (Correct Answer)</font></b>
# \
# \
# B) Strong-form efficient.
# \
# \
# C) Semistrong-form efficient.
# \
# \
# **Explanation:** \
# In a weak-form efficient market, market prices incorporate all market related information. In a semistrong-form efficient market, market prices incorporate all market and non-market public information. In a strong-form efficient market, market prices incorporate all market, non-market public, and private information. Positive risk-adjusted returns for specialists indicate that this market is not strong-form efficient as specialists have access to non-public information. Slow price adjustment to earnings surprises suggest this market is not semistrong-form efficient.
# \
# \
# (Module 43.1, LOS 43.d)
#
# <hr>
#
# **Question 38** \
# Participating preference shares are *most accurately* described as preferred stock that:
#
#
# **Answer:** \
# A) may be exchanged for the firm’s common shares at a predetermined ratio.
# \
# \
# <b><font color="green">B) receives extra dividends if the firm’s profits are greater than a predetermined level. (Correct Answer)</font></b>
# \
# \
# C) must be paid any omitted dividends from prior periods before the firm may pay dividends to common shareholders.
# \
# \
# **Explanation:**
# * Participating preference shares pay extra dividends if the firm's profits exceed a predetermined level.
# * Convertible preference shares may be exchanged for the firm's common shares at a predetermined ratio.
# * Cumulative preferred shares must be paid any omitted dividends from prior periods before the firm may pay dividends to common shareholders.
# \
# \
# (Module 44.1, LOS 44.a)
#
# <hr>
#
# **Question 39** \
# Compared with publicly traded firms, private firms *most likely* tend to:
#
#
# **Answer:** \
# <b><font color="green">A) focus more on long-term performance. (Correct Answer)</font></b>
# \
# \
# B) adopt stronger corporate governance policies.
# \
# \
# C) be more closely regulated and have higher compliance costs.
# \
# \
# **Explanation:** \
# Private equity firms tend to be better able to focus on long-term performance than publicly traded firms because they do not face pressure from public shareholders to produce positive short-term results. Because their shares are not publicly traded, private equity firms are not required to comply with the same financial reporting regulations as publicly traded firms. As a result, private equity firms have lower compliance costs than comparable publicly traded firms, but less scrutiny from public shareholders may result in weaker corporate governance.
# \
# \
# (Module 44.1, LOS 44.c)
#
# <hr>

# %% [markdown]
# **Question 40** \
# Global depository receipts (GDRs) are:
#
# **Answer:** \
# <b><font color="green">A) predominantly priced in U.S. dollars. (Correct Answer)</font></b>
# \
# \
# B) traded in United States markets.
# \
# \
# C) sponsored by the company issuing shares.
# \
# \
# **Explanation:** \
# Global depository receipts (GDRs) are typically denominated in U.S. dollars. GDRs are not listed on United States securities exchanges. Depository receipts that trade in the United States are called American depositary receipts (ADRs). GDRs may be sponsored by the issuing firm or <font color="red">unsponsored</font> and issued by the depository bank.
# \
# \
# (Module 44.2, LOS 44.d)
#
# <hr>
#
# **Question 41** \
# Other things equal, preferred stock is *most likely* to pay the highest dividend yield if it has which of the following features?
#
#
# **Answer:** \
# A) Putable.
# \
# \
# <b><font color="green">B) Callable. (Correct Answer)</font></b>
# \
# \
# C) Option-free.
# \
# \
# **Explanation:** \
# Because callable preferred stock has limited upside price potential, investors typically require it to pay a higher dividend yield than otherwise equivalent option-free or putable preferred stock.
# \
# \
# (Module 44.2, LOS 44.e)
#
# <hr>
#
# **Question 42** \
# The present value of an equity security's future cash flows is *most likely* to be significantly different from the company's:
#
#
# **Answer:** \
# <b><font color="green">A) book value per share. (Correct Answer)</font></b>
# \
# \
# B) market value per share.
# \
# \
# C) intrinsic value per share.
# \
# \
# **Explanation:** \
# A company's book value per share is typically not equal to its intrinsic value per share, since book value is based on the historical cost of assets. Intrinsic value is the present value of the security's future cash flows. The market value of a share is the cumulative investors' estimation of this intrinsic value, and market value is usually somewhat in line with the intrinsic value.
# \
# \
# (Module 44.2, LOS 44.g)
#
# <hr>
#
# **Question 43** \
# Which of the following is *most likely* to increase a firm's return on equity (ROE)?
#
#
# **Answer:** \
# A) Issuing new equity to retire debt.
# \
# \
# <b><font color="green">B) Issuing new debt to retire common stock. (Correct Answer)</font></b>
# \
# \
# C) A decrease in the market value of its common stock.
# \
# \
# **Explanation:** \
# Because the after-tax cost of debt is typically less than the earnings yield on the stock, issuing debt and repurchasing common stock is most likely to increase ROE, although the variability of net income will be increased (increased financial leverage). Changes in the market value of the common stock will not affect ROE.
# \
# \
# (Module 44.2, LOS 44.h)
#
# <hr>
#
# **Question 44** \
# An analyst uses a temporary supernormal growth model to value a common stock. The company paid a $2 dividend last year. The analyst expects dividends to grow at 15% each year for the next three years and then to resume a normal rate of 7% per year indefinitely. The analyst estimates that investors require a 12% return on the stock. The value of this common stock is *closest* to:
#
#
# **Answer:** \
# A) \\$39.
# \
# \
# <b><font color="green">B) \\$53. (Correct Answer)</font></b>
# \
# \
# C) \\$65.
# \
# \
# **Explanation:** \
# Calculate the dividends during the supernormal growth period using $g_s$ = 15%.
# \
# \
# $D_1 = D_0(1 + g_s) = \$2.00(1.15) = \$2.30$
# \
# \
# $D_2 = D_0(1 + g_s)^2 = \$2.00(1.15)^2 = \$2.645$
# \
# \
# $D_3 = D_0(1 + g_s)^3 = \$2.00(1.15)^3 = \$3.042$
# \
# \
# $D_3$ is the first dividend that *will grow* at a constant rate. Use this dividend to calculate the value of the stock at $t = 2$ using the infinite period DDM.
#
# $$
# P_2 = \frac{D_3}{k_e - g} = \frac{3.042}{0.12-0.07} = 60.84
# $$
# \
# \
# Calculate the present value of the cash flows discounted at $k_e$ of 12%.
#
# $\qquad \text{PV of }D_1 = \$2.30 / (1.12) = \$2.054$
#
# $\qquad \text{PV of }D_2 = \$2.645 / (1.12)^2 = \$2.109$
#
# $\qquad \text{PV of }P_2 = \$60.84 / (1.12)^2 = \$48.50$
# \
# \
# $V_s = \$52.664$
# \
# \
# (Module 48.2, LOS 48.h)
# <hr>
#
#
# **Question 45** \
# In valuing the stock of Evergreen Enterprises, an analyst compiles the following information about the firm:
#
# <table>
# <tbody>
#   <tr>
#     <td>Expected constant growth rate of dividends</td>
#     <td>6%</td>
#   </tr>
#   <tr>
#     <td>Next year's expected earnings per share</td>
#     <td>\$4.24</td>
#   </tr>
#   <tr>
#     <td>Expected retention ratio</td>
#     <td>62.5%</td>
#   </tr>
#   <tr>
#     <td>Required rate of return</td>
#     <td>11%</td>
#   </tr>
# </tbody>
# </table>
#
#
# The value of the firm's stock today is *closest* to:
#
#
#
# **Answer:** \
# <b><font color="green">A) \\$31.80. (Correct Answer)</font></b>
# \
# \
# B) \\$38.55.
# \
# \
# C) \\$53.00.
# \
# \
# **Explanation:** \
# The dividend payout ratio is `1 − expected retention ratio = 1 − 0.625 = 0.375` or `37.5%`.
# \
# \
# The leading (forward) P/E ratio is:
#
# $$
# \Large\frac{P_0}{E_1} = \frac{D_1/E_1}{r-g} = \frac{0.375}{0.11-0.06} = 7.50
# $$
# \
# \
# Multiplying the leading P/E ratio times forecast earnings per share gives the stock value:
# \
# \
# $\qquad\Large P_0 = \big(\frac{P_0}{E_1}\big)\big(E_1\big)  = 7.50(\$4.24) = \$31.80.  $
# \
# \
# (Module 48.3, LOS 48.k)
#
# <hr>
#
# **Question 46** \
# Enterprise value is *most appropriately* interpreted as:
#
#
# **Answer:** \
# <b><font color="green">A) the cost of a firm to a potential acquirer. (Correct Answer)</font></b>
# \
# \
# B) the estimated fair value of a firm’s tangible and intangible assets.
# \
# \
# C) the total market value of a firm’s outstanding debt and equity securities.
# \
# \
# **Explanation:** \
# Enterprise value (market value of a firm's equity and debt less the firm's cash and short-term securities investments) can be interpreted as the amount that would be needed to acquire a firm. Asset-based models are used to estimate the fair value of a firm's assets.
# \
# \
# (Module 48.3, LOS 48.l)
#
# <hr>
#
# **Question 47** \
# A drawback of using the price to book value ratio as a valuation tool is that book value:
#
# **Answer:** \
# A) is not appropriate for valuing firms with primarily financial assets..
# \
# \
# <b><font color="green">B) may not be an accurate indicator of the value of a company’s assets and equity. (Correct Answer)</font></b>
# \
# \
# C) is ineffective in valuing companies that are not expected to continue as going concerns.
# \
# \
# **Explanation:** \
# An important drawback of the price to book value ratio is that book values do not necessarily reflect market values. Book values of assets reported at amortized cost can be too low if prices have increased since the company acquired the assets. Book values can also be too high, for example, if technological changes have made some of a company's assets obsolete. The price to book value ratio is useful for valuing companies that primarily hold financial assets and for valuing companies that are expected to cease operations.
# \
# \
# (Module 48.3, LOS 48.f)
#
# <hr>
#
# **Question 48** \
# Cash flows from a fully amortizing security include:
#
#
# **Answer:** \
# <b><font color="green">A) no balloon payment. (Correct Answer)</font></b>
# \
# \
# B) a single balloon payment.
# \
# \
# C) a series of equal balloon payments.
# \
# \
# **Explanation:**
# * A balloon payment is a lump sum return of principal at maturity.
# * Fully amortizing securities are structured with equal periodic payments that include both interest and principal, so that there is <u>no balloon payment at maturity</u>.
# \
# \
# (Module 50.1, LOS 50.a)
#
# <hr>
#
# **Question 49** \
# The difference between on-the-run and off-the-run U.S. Treasury securities is that on-the-run Treasury securities are:
#
# **Answer:** \
# A) traded only in the primary market, while off-the-run Treasury securities are traded only in the secondary market..
# \
# \
# B) generally less actively traded than off-the-run Treasury securities and provide less reliable market yields.
# \
# \
# <b><font color="green">C) the most recently auctioned Treasury securities in each maturity, while off-the-run Treasury securities are issues auctioned previously. (Correct Answer)</font></b>
# \
# \
# **Explanation:** \
# On-the-run Treasury securities are the most recently auctioned issues. After they are auctioned in the primary market, on-the-run Treasury securities trade in the secondary market alongside off-the-run Treasury securities. On-the-run issues are generally the most actively traded Treasury securities.
# \
# \
# (Module 53.1, LOS 53.b)
#
# <hr>

# %% [markdown]
# **Question 50** \
# For a repurchase agreement, other things equal, when the security is of higher credit quality, then
#
#
# **Answer:** \
# <b><font color="green">A) both the repo rate and repo margin are lower. (Correct Answer)</font></b>
# \
# \
# B) the repo rate is higher but the repo margin is lower.
# \
# \
# C) the repo rate is lower but the repo margin is higher.
# \
# \
# **Explanation:**
# Compared with using a security with a lower credit rating, using a security with a higher credit rating will result in a lower repo rate (smaller difference between selling price and repurchase price) and a lower repo margin [the percentage that the sale price (i.e., the amount loaned) is less than the market value of the security].
# \
# \
# (Module 52.1, LOS 52.b)
#
# <hr>
